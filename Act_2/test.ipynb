# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data from a CSV file into a Pandas DataFrame
data = pd.read_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars.csv")

# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Temperature'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Temperature'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Temperature')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#          Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000
#
# Frequency Distribution:
#  3600     3
# 3218     2
# 2650     2
# 3625     2
# 3324     2
#         ..
# 10980    1
# 13720    1
# 19860    1
# 5300     1
# 37882    1
# Name: Temperature, Length: 228, dtype: int64

# %%
# Perform multiple replacements to standardize values in the "Color" column

data.replace({'Blue-White': 'Blue-white'}, regex=True,inplace=True)
data.replace({'Blue White': 'Blue-white'}, regex=True,inplace=True)
data.replace({'Blue white': 'Blue-white'}, regex=True,inplace=True)
data.replace({'yellowish': 'yellow-white'}, regex=True,inplace=True)
data.replace({'Yellowish': 'yellow-white'}, regex=True,inplace=True)
data.replace({'Yellowish White': 'yellow-white'}, regex=True,inplace=True)
data.replace({'White': 'white'}, regex=True,inplace=True)
data.replace({'Whitish': 'white'}, regex=True,inplace=True)
data.replace({'Orange-Red': 'Orange'}, regex=True,inplace=True)
data.replace({'Pale yellow orange': 'Orange'}, regex=True,inplace=True)
data.replace({'yellow-white white': 'yellow-white'}, regex=True,inplace=True)
data.replace({'white-Yellow': 'yellow-white'}, regex=True,inplace=True)

data.Color.value_counts()
# Out:
# Red             112
# Blue             56
# Blue-white       41
# yellow-white     15
# white            12
# Orange            4
# Name: Color, dtype: int64

# %%
# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Color'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Color'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Color')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#          Temperature              L            R         A_M        Type
# count    240.000000     240.000000   240.000000  240.000000  240.000000
# mean   10497.462500  107188.361635   237.157781    4.382396    2.500000
# std     9552.425037  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3344.250000       0.000865     0.102750   -6.232500    1.000000
# 50%     5776.000000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000
#
# Frequency Distribution:
#  Red             112
# Blue             56
# Blue-white       41
# yellow-white     15
# white            12
# Orange            4
# Name: Color, dtype: int64

# %%
# Define the column from which you want to delete data
column_name = 'Temperature', "Color"

# Define the percentage of data to delete (e.g., 20%)
delete_percentage = 0.2

# Calculate the number of rows to delete
num_rows_to_delete = int(len(data) * delete_percentage)

# Randomly select rows to delete
rows_to_delete = random.sample(data.index.tolist(), num_rows_to_delete)

# Replace the selected rows with a placeholder value or NaN
# You can use NaN to maintain the distribution, or use another placeholder value
data.loc[rows_to_delete, column_name] = None  # Use None for NaN or replace with your desired placeholder value

# %%
data.isnull().sum()
# Out:
# Temperature       48
# L                  0
# R                  0
# A_M                0
# Color             48
# Spectral_Class     0
# Type               0
# dtype: int64

# %%
# Write the modified DataFrame back to the CSV file
data.to_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars_mod.csv", index=False)

# %%
# Load data from a CSV file into a Pandas DataFrame
data = pd.read_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars_mod.csv")

# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Temperature'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Temperature'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Temperature')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#          Temperature              L            R         A_M        Type
# count    192.000000     240.000000   240.000000  240.000000  240.000000
# mean   10342.380208  107188.361635   237.157781    4.382396    2.500000
# std     9639.464091  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3341.750000       0.000865     0.102750   -6.232500    1.000000
# 50%     4406.500000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000
#
# Frequency Distribution:
#  2600.0     2
# 3625.0     2
# 3523.0     2
# 3324.0     2
# 3598.0     2
#           ..
# 10980.0    1
# 13720.0    1
# 19860.0    1
# 4526.0     1
# 37882.0    1
# Name: Temperature, Length: 184, dtype: int64

# %%
# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Color'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Color'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Color')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#          Temperature              L            R         A_M        Type
# count    192.000000     240.000000   240.000000  240.000000  240.000000
# mean   10342.380208  107188.361635   237.157781    4.382396    2.500000
# std     9639.464091  179432.244940   517.155763   10.532512    1.711394
# min     1939.000000       0.000080     0.008400  -11.920000    0.000000
# 25%     3341.750000       0.000865     0.102750   -6.232500    1.000000
# 50%     4406.500000       0.070500     0.762500    8.313000    2.500000
# 75%    15055.500000  198050.000000    42.750000   13.697500    4.000000
# max    40000.000000  849420.000000  1948.500000   20.060000    5.000000
#
# Frequency Distribution:
#  Red             94
# Blue            45
# Blue-white      28
# yellow-white    12
# white           10
# Orange           3
# Name: Color, dtype: int64

# %%
# Load data from a CSV file into a Pandas DataFrame
data = pd.read_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars_mod2.csv")

# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Temperature'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Temperature'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Temperature')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    192.000000     240.000000   240.000000  240.000000
# mean    119.50000  10342.380208  107188.361635   237.157781    4.382396
# std      69.42622   9639.464091  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4406.500000       0.070500     0.762500    8.313000
# 75%     179.25000  15055.500000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  2600.0     2
# 3625.0     2
# 3523.0     2
# 3324.0     2
# 3598.0     2
#           ..
# 10980.0    1
# 13720.0    1
# 19860.0    1
# 4526.0     1
# 37882.0    1
# Name: Temperature, Length: 184, dtype: int64

# %%
# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Color'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Color'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Color')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    192.000000     240.000000   240.000000  240.000000
# mean    119.50000  10342.380208  107188.361635   237.157781    4.382396
# std      69.42622   9639.464091  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4406.500000       0.070500     0.762500    8.313000
# 75%     179.25000  15055.500000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  Red             94
# Blue            45
# Blue-white      28
# yellow-white    12
# white           10
# Orange           3
# Name: Color, dtype: int64

# %%
# Load data from a CSV file into a Pandas DataFrame
data = pd.read_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars_mod3.csv")

# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Temperature'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Temperature'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Temperature')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    240.000000     240.000000   240.000000  240.000000
# mean    119.50000  10188.279167  107188.361635   237.157781    4.382396
# std      69.42622   9377.543949  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4287.000000       0.070500     0.762500    8.313000
# 75%     179.25000  14732.000000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  3146.0     3
# 3523.0     3
# 9700.0     3
# 3500.0     3
# 4287.0     3
#           ..
# 10574.0    1
# 8930.0     1
# 17200.0    1
# 14100.0    1
# 37882.0    1
# Name: Temperature, Length: 184, dtype: int64

# %%
# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Color'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Color'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Color')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    240.000000     240.000000   240.000000  240.000000
# mean    119.50000  10188.279167  107188.361635   237.157781    4.382396
# std      69.42622   9377.543949  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4287.000000       0.070500     0.762500    8.313000
# 75%     179.25000  14732.000000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  Red             94
# Blue            45
# Blue-white      28
# yellow-white    12
# white           10
# Orange           3
# Name: Color, dtype: int64

# %%
# Load data from a CSV file into a Pandas DataFrame
data = pd.read_csv("/home/jxn/Documents/UAQ/3er_semestre/Machine_Learning/DB/Stars_mod4.csv")

# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Temperature'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Temperature'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Temperature')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    240.000000     240.000000   240.000000  240.000000
# mean    119.50000  10188.279167  107188.361635   237.157781    4.382396
# std      69.42622   9377.543949  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4287.000000       0.070500     0.762500    8.313000
# 75%     179.25000  14732.000000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  3146.0     3
# 3523.0     3
# 9700.0     3
# 3500.0     3
# 4287.0     3
#           ..
# 10574.0    1
# 8930.0     1
# 17200.0    1
# 14100.0    1
# 37882.0    1
# Name: Temperature, Length: 184, dtype: int64

# %%
# Get summary statistics of numerical columns
numerical_summary = data.describe()

# Get the frequency distribution of a categorical column
categorical_distribution = data['Color'].value_counts()

# Visualize the data distribution
sns.set(style="whitegrid")  # Setting the style for seaborn plots
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.histplot(data['Color'], bins=20, kde=True)  # Histogram with KDE (Kernel Density Estimate)
plt.title('Data Distribution for Color')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Display summary statistics and frequency distribution
print("Summary Statistics:\n", numerical_summary)
print("\nFrequency Distribution:\n", categorical_distribution)
# Out:
# Summary Statistics:
#         Unnamed: 0   Temperature              L            R         A_M  \
# count   240.00000    240.000000     240.000000   240.000000  240.000000
# mean    119.50000  10188.279167  107188.361635   237.157781    4.382396
# std      69.42622   9377.543949  179432.244940   517.155763   10.532512
# min       0.00000   1939.000000       0.000080     0.008400  -11.920000
# 25%      59.75000   3341.750000       0.000865     0.102750   -6.232500
# 50%     119.50000   4287.000000       0.070500     0.762500    8.313000
# 75%     179.25000  14732.000000  198050.000000    42.750000   13.697500
# max     239.00000  40000.000000  849420.000000  1948.500000   20.060000
#
#              Type
# count  240.000000
# mean     2.500000
# std      1.711394
# min      0.000000
# 25%      1.000000
# 50%      2.500000
# 75%      4.000000
# max      5.000000
#
# Frequency Distribution:
#  Red             113
# Blue             57
# Blue-white       35
# yellow-white     18
# white            13
# Orange            4
# Name: Color, dtype: int64
